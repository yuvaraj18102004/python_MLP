# %%
#Write a Python program that takes a student’s marks as input

marks=int(input("Enter your marks :"))

if(marks>=90):
    print("Grade A")
if(marks>=75):
    print("Grade B")
if(marks>=50):
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks : 65
# Grade C

# %%
#ATM Withdrawal Check

b=12000
w=int(input("Enter the amount withdraw :"))

if(b>=w):
    if(w%100==0):
        print("Transaction sucessfull")
    else:
        print("Enter the number in multiples of 100")
else:
    print("insufficient balance")
# Out:
# Enter the amount withdraw : 6000
# Transaction sucessfull

# %%
#Take three sides of a triangle as input

a=float(input("Enter the A side of triangle :"))
b=float(input("Enter the B side of triangle :"))
c=float(input("Enter the C side of triangle :"))

if(a+b>c and b+c>a and a+c>b):
    if(a==b==c):
        print("Equilateral")
    if(a==b or a==c):
        print("Isosceles")
    else:
        print("Scalene")
else:
    print("Not a Triangle")
# Out:
# Enter the A side of triangle : 20
# Enter the B side of triangle : 20
# Enter the C side of triangle : 20
# Equilateral
# Isosceles

# %%
#Ask the user for age and citizenship (Indian/Other)

age=int(input("Enter your age :"))
citizenship=str(input("Enter your citizenship :"))

if(age>=18):
    if(citizenship=="india"):
        print("Eligible to Vote")
    else:
        print( "Not Eligible (Non-Citizen)")
else:
    print( "Not Eligible (Underage)")
# Out:
# Enter your age : 20
# Enter your citizenship : america
# Not Eligible (Non-Citizen)

# %%
#Take the total bill amount as input.

bill=float(input("Enter your bill amount :"))

if(bill>=5000):
    if(bill>=10000):
        print("your bill amount is :",(bill/100*20)-bill)
    else:
        print("your bill amount is :",(bill/100*10)-bill)
else:
    if(bill>=2000):
        print("your bill amount is :",(bill/100*5)-bill)
    else:
        print("No discount")
# Out:
# Enter your bill amount : 6000
# your bill amount is : -5400.0
