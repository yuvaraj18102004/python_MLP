# %%
# create all the 4 types of funtions for printing prime numbers from 2 to 20 

# fun without input and without return value


def prime():
    for i in range(2,21):
        if(i%2==1):
            print(i, end=" ")

# %%
prime()
# Out:
# 3 5 7 9 11 13 15 17 19

# %%
# fun with input and without return value

def prime(a,b):
    for i in range (a,b+1,1):
        for j in range (2,i,1):
            if(i%j==0):
                break
        else:
            print(i,end=" ")

# %%
prime(2,21)
# Out:
# 2 3 5 7 11 13 17 19

# %%
# fun without input and with return value

def prime1():
    pl = []
    for i in range (2,21,1):
        for j in range (2,i,1):
            if(i%j==0):
                break
        else:
            pl.append(i)
    return pl

# %%
prime1()
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %%
# fun with input and with return value

def prime4(a,b):
    pl = []
    for i range (a,b+1,1):
        for j in range (2,i,1):
            if(i%j==0):
                break
        else:
             pl.append(i)
    return pi
# Out:
#   Cell In[17], line 5
#     for i range (a,b+1,1):
#           ^
# SyntaxError: invalid syntax
