# %%
# read a float val from user then convert into in a integer

a=float(input("Enter the float value : "))
a_b=int(a)
print("your val is :",a_b)
print(type(a))
print(type(a_b))
# Out:
# Enter the float value :  62.8
# your val is : 62
# <class 'float'>
# <class 'int'>

# %%
# write a program to read student_name,id,email,3 subjects marks out of 100 and display they details in below formate

print("******* Student Details ********")
a=int(input("ID :"))
b=str(input("NAME :"))
c=str(input("EMAIL :"))
sub_1=int(input("sub_1 :"))
sub_2=int(input("sub_2 :"))
sub_3=int(input("sub_3 :"))
total=sub_1+sub_2+sub_3
percentage=total/3

print("ID=",a,"\nNAME=",b,"\nEMAIL=",c,"\nSUB_1=",sub_1,"\nSUB_2=",sub_2,"\nSUB_3=",sub_3,"\nGRAND_TOTAL=",total,"\nPERCENTAGE=",percentage)
print("******* All The best ********")
# Out:
# ******* Student Details ********
# ID : 5007
# NAME : Archana.S
# EMAIL : archana123@gmail.com
# sub_1 : 99
# sub_2 : 98
# sub_3 : 96
# ID= 5007
# NAME= Archana.S
# EMAIL= archana123@gmail.com
# SUB_1= 99
# SUB_2= 98
# SUB_3= 96
# GRAND_TOTAL= 293
# PERCENTAGE= 97.66666666666667
# ******* All The best ********
